# %%
import graphlab as gl
# Out:
# A newer version of GraphLab Create (v1.10.1) is available! Your current version is v1.9.
#
# You can use pip to upgrade the graphlab-create package. For more information see https://dato.com/products/create/upgrade.

# %%
db = gl.connect_odbc('DSN=wanderudb;UID=scraperro;PWD=walneyro')
# Out:
# 2016-06-21 15:30:34,499 [INFO] graphlab.cython.cy_server, 176: GraphLab Create v1.9 started. Logging: /tmp/graphlab_server_1466537433.log
# This non-commercial license of GraphLab Create is assigned to shawn.vo@gmail.com and will expire on April 17, 2017. For commercial licensing options, visit https://dato.com/buy/.

# %%
gl.canvas.set_target('ipynb')

# %%
megabussf = gl.SFrame.from_odbc(db, """ SELECT TO_CHAR(origintime, 'HH24:MI:SS') as origintime2,
                                    TO_CHAR(destinationtime, 'HH24:MI:SS') as destinationtime2,
                                    * FROM trips_prod 
                                    WHERE (carrier ='Megabus (bus)'
                                    AND CAST(datescraped AS DATE) = '2016-06-20'
                                    AND origincity = 'New York, NY')
                                    """)
# Out:
# ERROR: An unexpected error occurred while tokenizing input
# The following traceback may be corrupted or invalid
# The error message is: ('EOF in multi-line string', (1, 36))
# ---------------------------------------------------------------------------
# RuntimeError                              Traceback (most recent call last)
# <ipython-input-8-80050a7f0060> in <module>()
#       4                                     WHERE (carrier ='Megabus (bus)'
#       5                                     AND origincity = 'New York, NY')
# ----> 6                                     """)
#
# /Users/Shawn/anaconda/envs/mlenv/lib/python2.7/site-packages/graphlab/data_structures/sframe.pyc in from_odbc(cls, db, sql, verbose)
#    2075         """
#    2076         _mt._get_metric_tracker().track('sframe.from_odbc')
# -> 2077         result = db.execute_query(sql)
#    2078         if not isinstance(result, SFrame):
# ...

# %%
megabussf
# Out:
# Columns:
# 	origintime2	str
# 	destinationtime2	str
# 	id	int
# 	tripid	str
# 	carrier	str
# 	origintime	datetime
# 	origincity	str
# 	originlocation	str
# 	destinationtime	datetime
# 	destinationcity	str
# 	destinationlocation	str
# 	price	float
# 	duration	str
# 	features	str
# 	dateoftrip	datetime
# 	datescraped	datetime
# 	soldout	str
#
# Rows: 21
#
# Data:
# +-------------+------------------+--------+-------------------------------+
# | origintime2 | destinationtime2 |   id   |             tripid            |
# +-------------+------------------+--------+-------------------------------+
# |   06:00:00  |     10:35:00     | 897992 | 3a589bbc134d117513f9a4bae8... |
# |   08:00:00  |     12:35:00     | 901196 | f5504f95f0adebd9bc79339c60... |
# |   05:00:00  |     09:35:00     | 900344 | e1bad49470d281b8fcdbb165fd... |
# |   01:30:00  |     06:25:00     | 901183 | 6eda68dc63f2000c04221db2e3... |
# |   07:00:00  |     11:35:00     | 901190 | 223d66dc8033a69dc2a05b7b78... |
# ...

# %%
megabussf = gl.SFrame.from_odbc(db, """ SELECT TO_CHAR(origintime, 'HH24:MI:SS') as origintime2,
                                    TO_CHAR(destinationtime, 'HH24:MI:SS') as destinationtime2,
                                    * FROM trips_prod 
                                    WHERE (carrier ='Megabus (bus)'
                                    AND CAST(datescraped AS DATE) = '2016-06-20'
                                    AND CAST(dateoftrip AS DATE) = '2016-06-20'
                                    AND origincity = 'New York, NY')
                                    """)
